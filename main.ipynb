# %% [markdown]
# # Imports

# %%
import numpy as np
import wget

# %%
#file_name = wget.download("https://github.com/titiuo/RR-Image-Retrieval-using-Scene-Graphs/releases/download/v1.0.0/sg_test_images.zip")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 file_name = wget.download("https://github.com/titiuo/RR-Image-Retrieval-using-Scene-Graphs/releases/download/v1.0.0/sg_test_images.zip")
#
# File d:\Paris Cité\MVA\RR\.venv\Lib\site-packages\wget.py:526, in download(url, out, bar)
#     524 else:
#     525     binurl = url
# --> 526 (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527 filename = detect_filename(url, out, headers)
#     528 if outdir:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:268, in urlretrieve(url, filename, reporthook, data)
#     265 if reporthook:
#     266     reporthook(blocknum, bs, size)
# --> 268 while block := fp.read(bs):
#     269     read += len(block)
#     270     tfp.write(block)
#
# ...

# %%
from graph import SceneGraph, load_scene_graphs
from plot import visualize_graph, plot_scene_graph

# %%
import zipfile
import os

with zipfile.ZipFile('data.zip', 'r') as zip_ref:
    zip_ref.extractall('/tmp/test')

print(os.listdir('/tmp/test/'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 import zipfile
#       2 import os
# ----> 4 with zipfile.ZipFile('data.zip', 'r') as zip_ref:
#       5     zip_ref.extractall('/tmp/test')
#       7 print(os.listdir('/tmp/test/'))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:1321, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1319 while True:
#    1320     try:
# -> 1321         self.fp = io.open(file, filemode)
#    1322     except OSError:
#    1323         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.zip'

# %%
# !pip install unzip
# Out:
# ...
#   Using cached unzip-1.0.0-py3-none-any.whl
# ...
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Dataset

# %%
dataset_path = '../sg_dataset'

test_graph_path = dataset_path + '/sg_test_annotations.json'
train_graph_path = dataset_path + '/sg_train_annotations.json'
test_images_path = dataset_path + '/sg_test_images/'
train_images_path = dataset_path + '/sg_train_images/'

# %%
# --- 1. Load Data Once ---
print("Loading graphs and building vocabularies...")
graphs, v_obj, v_attr, v_rel = load_scene_graphs(train_graph_path)
print(f"Loaded {len(graphs)} graphs.")
# Out:
# Loading graphs and building vocabularies...
# Loaded 4000 graphs.

# %%
# --- 2. Pick a random index ---
index = np.random.randint(0, len(graphs))
print(f"Visualizing graph at index {index}")
# Out:
# Visualizing graph at index 2746

# %%
# --- 3. Pass the specific graph object to the visualizer ---
my_graph_object = graphs[index]

visualize_graph(my_graph_object, v_obj, v_attr, v_rel)
plot_scene_graph(my_graph_object, train_images_path, v_obj)
